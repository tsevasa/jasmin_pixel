# %%
import csv

csv_file = "_07_to_10_Intensity_Results.csv"
prefixes = ["A - 07", "A - 08", "A - 09", "A - 10", "B - 07", "B - 08", "B - 09", "B - 10"]
num_cells_cutoff = 10

counts = {
    p: {"active": 0, "inactive": 0}
    for p in prefixes
}

with open(csv_file, newline="") as f:
    reader = csv.DictReader(f)
    
    for row in reader:
        name = row["Name"]
        
        # Find matching prefix
        matched_prefix = None
        for p in prefixes:
            if name.startswith(p):
                matched_prefix = p
                break
        
        if matched_prefix is None:
            continue
        
        num_active = int(row["NumActive"])
        num_inactive = int(row["NumInactive"])
        total_cells = num_active + num_inactive
        
        if total_cells >= num_cells_cutoff:
            counts[matched_prefix]["active"] += num_active
            counts[matched_prefix]["inactive"] += num_inactive

# Print results
for p in prefixes:
    a = counts[p]["active"]
    i = counts[p]["inactive"]
    if a + i != 0:
        print(
            f"{p}: Active percentage = {100*a/(a+i):.2f}%, "
            f"Active = {a}, Inactive = {i}, Total = {a + i}"
        )
# Out:
# A - 07: Active percentage = 35.96%, Active = 1288, Inactive = 2294, Total = 3582
# A - 08: Active percentage = 26.10%, Active = 568, Inactive = 1608, Total = 2176
# A - 09: Active percentage = 34.33%, Active = 964, Inactive = 1844, Total = 2808
# A - 10: Active percentage = 28.56%, Active = 972, Inactive = 2431, Total = 3403
# B - 07: Active percentage = 38.00%, Active = 315, Inactive = 514, Total = 829
# B - 08: Active percentage = 15.45%, Active = 210, Inactive = 1149, Total = 1359
# B - 09: Active percentage = 32.48%, Active = 101, Inactive = 210, Total = 311
# B - 10: Active percentage = 35.53%, Active = 1196, Inactive = 2170, Total = 3366

# %%
# pip install numpy matplotlib jupyter pandas opencv-python scikit-image ipywidgets ipympl
import os
import cv2
import numpy as np
import pandas as pd
from skimage import measure, morphology
from skimage.io import imread
from tkinter import filedialog, Tk
import matplotlib.pyplot as plt
import ipywidgets as widgets
from IPython.display import display, clear_output
from scipy.ndimage import convolve
import re
plt.rcParams['figure.figsize'] = [8, 8]

GUI_INPUT = False

# Set path and min-max paramters
if GUI_INPUT:
    Tk().withdraw()
    input_folder = filedialog.askdirectory(title="Choose input folder")
    output_file = filedialog.asksaveasfilename(defaultextension=".csv", title="Choose where to save results", initialfile="Intensity_Results.csv")
    min_val = float(input("Enter intensity minimum (e.g. 0): "))
    max_val = float(input("Enter intensity maximum (e.g. 16000): "))
else:
    input_folder = os.getcwd() # Current folder
    parent_name = os.path.basename(input_folder)
    output_file = os.path.join(input_folder, f"_{parent_name}_Intensity_Results.csv")
    min_val = 500
    max_val = 25000

# Collect image files
files = sorted(os.listdir(input_folder))
filtered_files = [f for f in files if f.endswith("tif")]

# Save image files to list
images = []
for j in range(0, len(filtered_files), 2):
    int_path = os.path.join(input_folder, filtered_files[j+1])
    nuc_path = os.path.join(input_folder, filtered_files[j])
    int_img = imread(int_path, as_gray=True)
    nuc_img = imread(nuc_path, as_gray=True)
    name = filtered_files[j].split(".")[0]

    # Scale intensity image and Gaussian blur
    int_img = (np.clip(int_img, min_val, max_val) - min_val) / (max_val - min_val)

    nuc_img = (np.clip(nuc_img, min_val, max_val) - min_val) / (max_val - min_val)
    # nuc_img = 1.0 - nuc_img


    background = cv2.GaussianBlur(int_img, (91, 91), 0)
    int_img = cv2.subtract(int_img, background)
    images.append([name, int_img, nuc_img, None, None])

    if j != 0 and j % 30 == 0:
        print(f"{j} images done")
# Out:
# 30 images done
# 60 images done
# 90 images done
# 120 images done
# 150 images done
# 180 images done
# 210 images done
# 240 images done
# 270 images done
# 300 images done
# 330 images done
# 360 images done
# 390 images done
# 420 images done
# 450 images done
# 480 images done
# 510 images done
# 540 images done
# 570 images done

# %%
GUI_IMAGES = False

def get_default_params(name):
    # minthresh, maxthresh, minsize, mineccentricity, minsolidity
    return 0.25, 1.0, 150, 0.5, 0.89

def get_binary(nuc_img, min_thresh, maxthresh, min_size, mineccentricity, minsolidity):
    binary = np.logical_and(nuc_img > min_thresh, nuc_img < maxthresh).astype(np.uint8)
    binary = morphology.remove_small_objects(binary.astype(bool), max_size=min_size)
    binary = morphology.remove_small_holes(binary, max_size=min_size)

    label_img = measure.label(binary)
    props = measure.regionprops(label_img)
    for prop in props:
        if prop.eccentricity < mineccentricity or prop.solidity < minsolidity:
            binary[label_img == prop.label] = False

    return binary

# %matplotlib inline
def GUI_binary(entry):
    name = entry[0]
    nuc_img = entry[2]
    slider_minthresh_initial, slider_maxthresh_initial, slider_minsize_initial, slider_mineccentricity_initial, slider_minsolidity_initial = get_default_params(name)

    slider_minthresh = widgets.FloatSlider(value=slider_minthresh_initial , min=0.0, max=1.0, step=0.01, description="Min Threshold:", continuous_update=False)
    slider_maxthresh = widgets.FloatSlider(value=slider_maxthresh_initial, min=0.0, max=1.0, step=0.01, description="Max Threshold:", continuous_update=False)
    slider_minsize = widgets.IntSlider(value=slider_minsize_initial, min=0, max=800, step=10, description="Min size:", continuous_update=False)
    slider_mineccentricity = widgets.FloatSlider(value=slider_mineccentricity_initial, min=0, max=1, step=0.01, description="Min Eccentricity:", continuous_update=False)
    slider_minsolidity = widgets.FloatSlider(value=slider_minsolidity_initial, min=0, max=1, step=0.01, description="Min Solidity:", continuous_update=False)
    button = widgets.Button(description="Confirm", button_style="success")
    output = widgets.Output()

    plt.close()
    plt.figure()

    def update_image(change=None):
        with output:
            binary = get_binary(nuc_img, slider_minthresh.value, slider_maxthresh.value, slider_minsize.value, slider_mineccentricity.value, slider_minsolidity.value)
            clear_output(wait=True)
            plt.title(name)
            plt.axis('off')
            plt.subplots_adjust(left=0, right=1, top=1, bottom=0)
            plt.imshow(binary , cmap='gray')
            plt.show()

    def on_confirm_clicked(b=None):
        """Store the confirmed value and clear the plot"""
        binary = get_binary(nuc_img, slider_minthresh.value, slider_maxthresh.value, slider_minsize.value, slider_mineccentricity.value, slider_minsolidity.value)
        plt.close()
        container.close()
        display(f"Confirmed values for \"{name}\": min_thresh = {slider_minthresh.value}, max_thresh = {slider_maxthresh.value}, min_size = {slider_minsize.value}, mineccentricity = {slider_mineccentricity.value}, minsolidity = {slider_minsolidity.value}")
        entry[3] = binary
        entry[4] = {"min_thresh": slider_minthresh.value, "max_thresh": slider_maxthresh.value, "min_size": slider_minsize.value, "mineccentricity": slider_mineccentricity.value, "minsolidity": slider_minsolidity.value}

    slider_minthresh.observe(update_image, names="value")
    slider_maxthresh.observe(update_image, names="value")
    slider_minsize.observe(update_image, names="value")
    slider_mineccentricity.observe(update_image, names="value")
    slider_minsolidity.observe(update_image, names="value")
    container = widgets.VBox([slider_minthresh, slider_maxthresh, slider_minsize, slider_mineccentricity, slider_minsolidity, button, output])
    display(container)
    update_image()
    button.on_click(on_confirm_clicked)

if GUI_IMAGES:
    for entry in images:
        GUI_binary(entry)
else:
    for entry in images:
        name = entry[0]
        nuc_img = entry[2]
        slider_minthresh_initial, slider_maxthresh_initial, slider_minsize_initial, slider_mineccentricity_initial, slider_minsolidity_initial = get_default_params(name)

        binary = get_binary(nuc_img, slider_minthresh_initial, slider_maxthresh_initial, slider_minsize_initial, slider_mineccentricity_initial, slider_minsolidity_initial)
        print(f"Confirmed values for \"{name}\": min_thresh = {slider_minthresh_initial}, max_thresh = {slider_maxthresh_initial}, min_size = {slider_minsize_initial}, mineccentricity = {slider_mineccentricity_initial}, minsolidity = {slider_minsolidity_initial}")
        entry[3] = binary
        entry[4] = {"min_thresh": slider_minthresh_initial, "max_thresh": slider_maxthresh_initial, "min_size": slider_minsize_initial, "mineccentricity": slider_mineccentricity_initial, "minsolidity": slider_minsolidity_initial}
# Out:
# Confirmed values for "E - 07(fld 01 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 07(fld 02 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 07(fld 03 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 07(fld 04 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 07(fld 05 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 07(fld 06 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 07(fld 07 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 07(fld 08 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 07(fld 09 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 07(fld 10 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 07(fld 11 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 07(fld 12 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 07(fld 13 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 07(fld 14 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 07(fld 15 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 07(fld 16 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 07(fld 17 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 07(fld 18 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 07(fld 19 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 07(fld 20 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 07(fld 21 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 07(fld 22 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 07(fld 23 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 07(fld 24 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 07(fld 25 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 08(fld 01 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 08(fld 02 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 08(fld 03 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 08(fld 04 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 08(fld 05 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 08(fld 06 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 08(fld 07 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 08(fld 08 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 08(fld 09 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 08(fld 10 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 08(fld 11 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 08(fld 12 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 08(fld 13 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 08(fld 14 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 08(fld 15 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 08(fld 16 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 08(fld 17 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 08(fld 18 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 08(fld 19 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 08(fld 20 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 08(fld 21 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 08(fld 22 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 08(fld 23 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 08(fld 24 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 08(fld 25 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 09(fld 01 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 09(fld 02 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 09(fld 03 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 09(fld 04 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 09(fld 05 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 09(fld 06 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 09(fld 07 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 09(fld 08 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 09(fld 09 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 09(fld 10 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 09(fld 11 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 09(fld 12 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 09(fld 13 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 09(fld 14 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 09(fld 15 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 09(fld 16 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 09(fld 17 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 09(fld 18 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 09(fld 19 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 09(fld 20 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 09(fld 21 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 09(fld 22 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 09(fld 23 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 09(fld 24 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 09(fld 25 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 10(fld 01 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 10(fld 02 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 10(fld 03 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 10(fld 04 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 10(fld 05 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 10(fld 06 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 10(fld 07 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 10(fld 08 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 10(fld 09 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 10(fld 10 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 10(fld 11 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 10(fld 12 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 10(fld 13 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 10(fld 14 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 10(fld 15 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 10(fld 16 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 10(fld 17 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 10(fld 18 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 10(fld 19 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 10(fld 20 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 10(fld 21 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 10(fld 22 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 10(fld 23 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 10(fld 24 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "E - 10(fld 25 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 07(fld 01 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 07(fld 02 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 07(fld 03 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 07(fld 04 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 07(fld 05 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 07(fld 06 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 07(fld 07 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 07(fld 08 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 07(fld 09 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 07(fld 10 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 07(fld 11 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 07(fld 12 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 07(fld 13 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 07(fld 14 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 07(fld 15 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 07(fld 16 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 07(fld 17 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 07(fld 18 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 07(fld 19 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 07(fld 20 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 07(fld 21 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 07(fld 22 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 07(fld 23 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 07(fld 24 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 07(fld 25 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 08(fld 01 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 08(fld 02 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 08(fld 03 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 08(fld 04 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 08(fld 05 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 08(fld 06 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 08(fld 07 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 08(fld 08 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 08(fld 09 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 08(fld 10 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 08(fld 11 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 08(fld 12 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 08(fld 13 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 08(fld 14 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 08(fld 15 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 08(fld 16 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 08(fld 17 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 08(fld 18 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 08(fld 19 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 08(fld 20 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 08(fld 21 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 08(fld 22 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 08(fld 23 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 08(fld 24 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 08(fld 25 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 09(fld 01 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 09(fld 02 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 09(fld 03 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 09(fld 04 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 09(fld 05 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 09(fld 06 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 09(fld 07 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 09(fld 08 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 09(fld 09 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 09(fld 10 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 09(fld 11 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 09(fld 12 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 09(fld 13 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 09(fld 14 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 09(fld 15 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 09(fld 16 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 09(fld 17 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 09(fld 18 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 09(fld 19 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 09(fld 20 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 09(fld 21 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 09(fld 22 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 09(fld 23 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 09(fld 24 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 09(fld 25 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 10(fld 01 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 10(fld 02 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 10(fld 03 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 10(fld 04 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 10(fld 05 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 10(fld 06 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 10(fld 07 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 10(fld 08 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 10(fld 09 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 10(fld 10 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 10(fld 11 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 10(fld 12 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 10(fld 13 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 10(fld 14 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 10(fld 15 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 10(fld 16 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 10(fld 17 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 10(fld 18 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 10(fld 19 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 10(fld 20 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 10(fld 21 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 10(fld 22 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 10(fld 23 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 10(fld 24 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "F - 10(fld 25 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 07(fld 01 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 07(fld 02 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 07(fld 03 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 07(fld 04 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 07(fld 05 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 07(fld 06 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 07(fld 07 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 07(fld 08 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 07(fld 09 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 07(fld 10 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 07(fld 11 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 07(fld 12 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 07(fld 13 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 07(fld 14 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 07(fld 15 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 07(fld 16 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 07(fld 17 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 07(fld 18 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 07(fld 19 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 07(fld 20 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 07(fld 21 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 07(fld 22 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 07(fld 23 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 07(fld 24 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 07(fld 25 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 08(fld 01 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 08(fld 02 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 08(fld 03 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 08(fld 04 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 08(fld 05 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 08(fld 06 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 08(fld 07 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 08(fld 08 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 08(fld 09 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 08(fld 10 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 08(fld 11 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 08(fld 12 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 08(fld 13 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 08(fld 14 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 08(fld 15 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 08(fld 16 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 08(fld 17 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 08(fld 18 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 08(fld 19 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 08(fld 20 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 08(fld 21 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 08(fld 22 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 08(fld 23 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 08(fld 24 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 08(fld 25 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 09(fld 01 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 09(fld 02 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 09(fld 03 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 09(fld 04 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 09(fld 05 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 09(fld 06 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 09(fld 07 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 09(fld 08 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 09(fld 09 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 09(fld 10 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 09(fld 11 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 09(fld 12 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 09(fld 13 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 09(fld 14 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 09(fld 15 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 09(fld 16 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 09(fld 17 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 09(fld 18 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 09(fld 19 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 09(fld 20 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 09(fld 21 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 09(fld 22 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 09(fld 23 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 09(fld 24 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 09(fld 25 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 10(fld 01 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 10(fld 02 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 10(fld 03 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 10(fld 04 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 10(fld 05 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 10(fld 06 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 10(fld 07 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 10(fld 08 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 10(fld 09 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 10(fld 10 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 10(fld 11 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 10(fld 12 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 10(fld 13 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 10(fld 14 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 10(fld 15 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 10(fld 16 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 10(fld 17 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 10(fld 18 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 10(fld 19 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 10(fld 20 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 10(fld 21 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 10(fld 22 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 10(fld 23 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 10(fld 24 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89
# Confirmed values for "G - 10(fld 25 wv DAPI - DAPI)": min_thresh = 0.25, max_thresh = 1.0, min_size = 150, mineccentricity = 0.5, minsolidity = 0.89

# %%
expand_size = 2
shrink_size = 2

def get_proportion_pixels_in_category(values, intensity_categories):
    # Count number of pixels of ROI in intensity categories
    number_pixels_in_category = []
    for i in range(len(intensity_categories)):
        number_pixels_in_category.append(int(np.sum(values <= intensity_categories[i])))

    proportion_pixels_in_category = []
    for i in range(len(number_pixels_in_category)):
        if i == 0:
            proportion_pixels_in_category.append(number_pixels_in_category[0])
        else:
            proportion_pixels_in_category.append(number_pixels_in_category[i] - number_pixels_in_category[i-1])
    proportion_pixels_in_category = np.array(proportion_pixels_in_category) / len(values)
    return proportion_pixels_in_category

results = []
all_mask_list = []
all_perinuclear_list = []
all_interior_list = []
all_perinuclear_active_list = []
all_perinuclear_inactive_list = []
for entry in images:
    name, int_img, nuc_img, binary, params = entry
    all_mask = np.full(np.shape(int_img), False, dtype=bool)
    all_perinuclear = np.full(np.shape(int_img), False, dtype=bool)
    all_interior = np.full(np.shape(int_img), False, dtype=bool)
    all_perinuclear_active = np.full(np.shape(int_img), False, dtype=bool)
    all_perinuclear_inactive = np.full(np.shape(int_img), False, dtype=bool)
    active = 0
    inactive = 0

    # Label nuclei
    labels = measure.label(binary)
    props = measure.regionprops(labels)

    # Get relative percentile intensities in image
    sorted_values = np.sort(int_img.flatten())
    num_values = np.shape(sorted_values)[0]
    intensity_categories_rel_to_img = [float(sorted_values[int(num_values * 0.4)]), float(sorted_values[int(num_values * 0.6)]), float(sorted_values[int(num_values * 0.7)]), float(sorted_values[int(num_values * 0.85)]), 1.0]
    
    dark_intensity_cutoff = float(sorted_values[int(num_values * 0.03)])
    active_relative_high_percentile_interior_intensity_brightness = 0.15

    for idx, prop in enumerate(props, start=1):
        mask = (labels == prop.label).astype(np.uint8)
        all_mask = np.logical_or(all_mask, mask)

        # Perinuclear region ROI = expand - shrink
        shrink = cv2.erode(mask, np.ones((int(shrink_size*2+1), int(shrink_size*2+1)), np.uint8), iterations=1)
        expand = cv2.dilate(mask, np.ones((int(expand_size*2+1), int(expand_size*2+1)), np.uint8), iterations=1)
        perinuclear = ((expand - shrink) > 0).astype(bool)

        # Interior region = shrink
        interior = (shrink > 0).astype(bool)

        # Get values and measure intensity inside perinuclear mask
        values = int_img[perinuclear]
        mean_intensity = values.mean()
        all_perinuclear = np.logical_or(all_perinuclear, perinuclear)

        # Get values and measure intensity inside interior mask
        values_interior = int_img[interior]
        num_values_interior = values_interior.size
        mean_intensity_interior = values_interior.mean() if num_values_interior != 0 else 0
        all_interior = np.logical_or(all_interior, interior)
        intensity_categories_rel_to_interior = mean_intensity_interior + np.array([-0.1, 0.0, 0.09, 0.15, 1.0])
        
        # Count number of pixels of ROI in intensity categories
        proportion_pixels_in_category_rel_to_interior = get_proportion_pixels_in_category(values, intensity_categories_rel_to_interior)
        proportion_pixels_in_category_rel_to_img = get_proportion_pixels_in_category(values, intensity_categories_rel_to_img)

        # Get high percentile brightness of interior
        if num_values_interior != 0:
            sorted_values_interior = np.sort(values_interior.flatten())
            high_percentile_intensity_interior = float(sorted_values_interior[int(num_values_interior * 0.2)])

        # Classify ROI
        is_active = False
        if proportion_pixels_in_category_rel_to_img[4] >= 0.5:
            is_active = True
        elif num_values_interior != 0 and high_percentile_intensity_interior >= dark_intensity_cutoff + active_relative_high_percentile_interior_intensity_brightness:
            is_active = True
        elif proportion_pixels_in_category_rel_to_interior[0] >= 0.5:
            is_active = False
        elif proportion_pixels_in_category_rel_to_interior[4] >= 0.5:
            is_active = True
        elif proportion_pixels_in_category_rel_to_interior[0] + proportion_pixels_in_category_rel_to_interior[1] >= 0.5:
            is_active = False
        elif proportion_pixels_in_category_rel_to_interior[3] + proportion_pixels_in_category_rel_to_interior[4] >= 0.5:
            is_active = True
        elif proportion_pixels_in_category_rel_to_interior[0] + proportion_pixels_in_category_rel_to_interior[1] + proportion_pixels_in_category_rel_to_interior[2] >= 0.5:
            is_active = False
        else:
            is_active = True
        
        if is_active:
            # Cell is active
            active += 1
            all_perinuclear_active = np.logical_or(all_perinuclear_active, perinuclear)
        else:
            # Cell is inactive
            inactive += 1
            all_perinuclear_inactive = np.logical_or(all_perinuclear_inactive, perinuclear)

    results.append({
        "Name": name,
        "NumCells": active + inactive,
        "NumActive": active,
        "NumInactive": inactive,
        "FractionActive": active / (active + inactive) if active + inactive > 0 else "NaN",
        "FractionInactive": inactive / (active + inactive) if active + inactive > 0 else "NaN",
        "Parameters": str(params)
    })
    
    all_mask_list.append(all_mask)
    all_perinuclear_list.append(all_perinuclear)
    all_interior_list.append(all_interior)
    all_perinuclear_active_list.append(all_perinuclear_active)
    all_perinuclear_inactive_list.append(all_perinuclear_inactive)
    if active + inactive > 0:
        print(f"\"{name}\": Active: {active}, inactive: {inactive}. Percentage active: {100.0 * active / (active + inactive) :.1f}%.")
    else:
        print(f"\"{name}\": Active: {active}, inactive: {inactive}. Percentage active: NaN.")
    
    # break

pd.DataFrame(results).to_csv(output_file, index=False, mode="w")
print(f"Analysis complete! Results saved to {output_file}.")
# Out:
# "E - 07(fld 01 wv DAPI - DAPI)": Active: 23, inactive: 23. Percentage active: 50.0%.
# "E - 07(fld 02 wv DAPI - DAPI)": Active: 40, inactive: 89. Percentage active: 31.0%.
# "E - 07(fld 03 wv DAPI - DAPI)": Active: 33, inactive: 112. Percentage active: 22.8%.
# "E - 07(fld 04 wv DAPI - DAPI)": Active: 24, inactive: 52. Percentage active: 31.6%.
# "E - 07(fld 05 wv DAPI - DAPI)": Active: 5, inactive: 1. Percentage active: 83.3%.
# "E - 07(fld 06 wv DAPI - DAPI)": Active: 23, inactive: 98. Percentage active: 19.0%.
# "E - 07(fld 07 wv DAPI - DAPI)": Active: 24, inactive: 202. Percentage active: 10.6%.
# "E - 07(fld 08 wv DAPI - DAPI)": Active: 4, inactive: 182. Percentage active: 2.2%.
# "E - 07(fld 09 wv DAPI - DAPI)": Active: 22, inactive: 105. Percentage active: 17.3%.
# "E - 07(fld 10 wv DAPI - DAPI)": Active: 25, inactive: 13. Percentage active: 65.8%.
# "E - 07(fld 11 wv DAPI - DAPI)": Active: 0, inactive: 12. Percentage active: 0.0%.
# "E - 07(fld 12 wv DAPI - DAPI)": Active: 4, inactive: 181. Percentage active: 2.2%.
# "E - 07(fld 13 wv DAPI - DAPI)": Active: 2, inactive: 185. Percentage active: 1.1%.
# "E - 07(fld 14 wv DAPI - DAPI)": Active: 8, inactive: 8. Percentage active: 50.0%.
# "E - 07(fld 15 wv DAPI - DAPI)": Active: 21, inactive: 32. Percentage active: 39.6%.
# "E - 07(fld 16 wv DAPI - DAPI)": Active: 10, inactive: 62. Percentage active: 13.9%.
# "E - 07(fld 17 wv DAPI - DAPI)": Active: 22, inactive: 180. Percentage active: 10.9%.
# "E - 07(fld 18 wv DAPI - DAPI)": Active: 7, inactive: 191. Percentage active: 3.5%.
# "E - 07(fld 19 wv DAPI - DAPI)": Active: 21, inactive: 97. Percentage active: 17.8%.
# "E - 07(fld 20 wv DAPI - DAPI)": Active: 21, inactive: 10. Percentage active: 67.7%.
# "E - 07(fld 21 wv DAPI - DAPI)": Active: 1, inactive: 0. Percentage active: 100.0%.
# "E - 07(fld 22 wv DAPI - DAPI)": Active: 21, inactive: 27. Percentage active: 43.8%.
# "E - 07(fld 23 wv DAPI - DAPI)": Active: 39, inactive: 22. Percentage active: 63.9%.
# "E - 07(fld 24 wv DAPI - DAPI)": Active: 11, inactive: 20. Percentage active: 35.5%.
# "E - 07(fld 25 wv DAPI - DAPI)": Active: 0, inactive: 0. Percentage active: NaN.
# "E - 08(fld 01 wv DAPI - DAPI)": Active: 0, inactive: 0. Percentage active: NaN.
# "E - 08(fld 02 wv DAPI - DAPI)": Active: 1, inactive: 0. Percentage active: 100.0%.
# "E - 08(fld 03 wv DAPI - DAPI)": Active: 1, inactive: 0. Percentage active: 100.0%.
# "E - 08(fld 04 wv DAPI - DAPI)": Active: 0, inactive: 0. Percentage active: NaN.
# "E - 08(fld 05 wv DAPI - DAPI)": Active: 0, inactive: 0. Percentage active: NaN.
# "E - 08(fld 06 wv DAPI - DAPI)": Active: 0, inactive: 1. Percentage active: 0.0%.
# "E - 08(fld 07 wv DAPI - DAPI)": Active: 0, inactive: 0. Percentage active: NaN.
# "E - 08(fld 08 wv DAPI - DAPI)": Active: 0, inactive: 0. Percentage active: NaN.
# "E - 08(fld 09 wv DAPI - DAPI)": Active: 0, inactive: 0. Percentage active: NaN.
# "E - 08(fld 10 wv DAPI - DAPI)": Active: 0, inactive: 0. Percentage active: NaN.
# "E - 08(fld 11 wv DAPI - DAPI)": Active: 0, inactive: 0. Percentage active: NaN.
# "E - 08(fld 12 wv DAPI - DAPI)": Active: 0, inactive: 0. Percentage active: NaN.
# "E - 08(fld 13 wv DAPI - DAPI)": Active: 0, inactive: 3. Percentage active: 0.0%.
# "E - 08(fld 14 wv DAPI - DAPI)": Active: 1, inactive: 1. Percentage active: 50.0%.
# "E - 08(fld 15 wv DAPI - DAPI)": Active: 0, inactive: 0. Percentage active: NaN.
# "E - 08(fld 16 wv DAPI - DAPI)": Active: 1, inactive: 0. Percentage active: 100.0%.
# "E - 08(fld 17 wv DAPI - DAPI)": Active: 0, inactive: 1. Percentage active: 0.0%.
# "E - 08(fld 18 wv DAPI - DAPI)": Active: 0, inactive: 0. Percentage active: NaN.
# "E - 08(fld 19 wv DAPI - DAPI)": Active: 0, inactive: 1. Percentage active: 0.0%.
# "E - 08(fld 20 wv DAPI - DAPI)": Active: 0, inactive: 0. Percentage active: NaN.
# "E - 08(fld 21 wv DAPI - DAPI)": Active: 0, inactive: 0. Percentage active: NaN.
# "E - 08(fld 22 wv DAPI - DAPI)": Active: 0, inactive: 1. Percentage active: 0.0%.
# "E - 08(fld 23 wv DAPI - DAPI)": Active: 43, inactive: 25. Percentage active: 63.2%.
# "E - 08(fld 24 wv DAPI - DAPI)": Active: 47, inactive: 4. Percentage active: 92.2%.
# "E - 08(fld 25 wv DAPI - DAPI)": Active: 0, inactive: 0. Percentage active: NaN.
# "E - 09(fld 01 wv DAPI - DAPI)": Active: 78, inactive: 5. Percentage active: 94.0%.
# "E - 09(fld 02 wv DAPI - DAPI)": Active: 161, inactive: 14. Percentage active: 92.0%.
# "E - 09(fld 03 wv DAPI - DAPI)": Active: 129, inactive: 7. Percentage active: 94.9%.
# "E - 09(fld 04 wv DAPI - DAPI)": Active: 118, inactive: 11. Percentage active: 91.5%.
# "E - 09(fld 05 wv DAPI - DAPI)": Active: 3, inactive: 1. Percentage active: 75.0%.
# "E - 09(fld 06 wv DAPI - DAPI)": Active: 112, inactive: 11. Percentage active: 91.1%.
# "E - 09(fld 07 wv DAPI - DAPI)": Active: 63, inactive: 9. Percentage active: 87.5%.
# "E - 09(fld 08 wv DAPI - DAPI)": Active: 88, inactive: 17. Percentage active: 83.8%.
# "E - 09(fld 09 wv DAPI - DAPI)": Active: 100, inactive: 14. Percentage active: 87.7%.
# "E - 09(fld 10 wv DAPI - DAPI)": Active: 19, inactive: 10. Percentage active: 65.5%.
# "E - 09(fld 11 wv DAPI - DAPI)": Active: 46, inactive: 7. Percentage active: 86.8%.
# "E - 09(fld 12 wv DAPI - DAPI)": Active: 41, inactive: 0. Percentage active: 100.0%.
# "E - 09(fld 13 wv DAPI - DAPI)": Active: 72, inactive: 15. Percentage active: 82.8%.
# "E - 09(fld 14 wv DAPI - DAPI)": Active: 91, inactive: 59. Percentage active: 60.7%.
# "E - 09(fld 15 wv DAPI - DAPI)": Active: 31, inactive: 34. Percentage active: 47.7%.
# "E - 09(fld 16 wv DAPI - DAPI)": Active: 88, inactive: 14. Percentage active: 86.3%.
# "E - 09(fld 17 wv DAPI - DAPI)": Active: 70, inactive: 5. Percentage active: 93.3%.
# "E - 09(fld 18 wv DAPI - DAPI)": Active: 66, inactive: 7. Percentage active: 90.4%.
# "E - 09(fld 19 wv DAPI - DAPI)": Active: 126, inactive: 36. Percentage active: 77.8%.
# "E - 09(fld 20 wv DAPI - DAPI)": Active: 27, inactive: 23. Percentage active: 54.0%.
# "E - 09(fld 21 wv DAPI - DAPI)": Active: 15, inactive: 3. Percentage active: 83.3%.
# "E - 09(fld 22 wv DAPI - DAPI)": Active: 111, inactive: 31. Percentage active: 78.2%.
# "E - 09(fld 23 wv DAPI - DAPI)": Active: 101, inactive: 25. Percentage active: 80.2%.
# "E - 09(fld 24 wv DAPI - DAPI)": Active: 56, inactive: 6. Percentage active: 90.3%.
# "E - 09(fld 25 wv DAPI - DAPI)": Active: 0, inactive: 0. Percentage active: NaN.
# "E - 10(fld 01 wv DAPI - DAPI)": Active: 0, inactive: 0. Percentage active: NaN.
# "E - 10(fld 02 wv DAPI - DAPI)": Active: 93, inactive: 21. Percentage active: 81.6%.
# "E - 10(fld 03 wv DAPI - DAPI)": Active: 166, inactive: 50. Percentage active: 76.9%.
# "E - 10(fld 04 wv DAPI - DAPI)": Active: 0, inactive: 3. Percentage active: 0.0%.
# "E - 10(fld 05 wv DAPI - DAPI)": Active: 0, inactive: 0. Percentage active: NaN.
# "E - 10(fld 06 wv DAPI - DAPI)": Active: 1, inactive: 0. Percentage active: 100.0%.
# "E - 10(fld 07 wv DAPI - DAPI)": Active: 154, inactive: 19. Percentage active: 89.0%.
# "E - 10(fld 08 wv DAPI - DAPI)": Active: 210, inactive: 40. Percentage active: 84.0%.
# "E - 10(fld 09 wv DAPI - DAPI)": Active: 206, inactive: 34. Percentage active: 85.8%.
# "E - 10(fld 10 wv DAPI - DAPI)": Active: 10, inactive: 8. Percentage active: 55.6%.
# "E - 10(fld 11 wv DAPI - DAPI)": Active: 0, inactive: 0. Percentage active: NaN.
# "E - 10(fld 12 wv DAPI - DAPI)": Active: 49, inactive: 3. Percentage active: 94.2%.
# "E - 10(fld 13 wv DAPI - DAPI)": Active: 118, inactive: 11. Percentage active: 91.5%.
# "E - 10(fld 14 wv DAPI - DAPI)": Active: 145, inactive: 14. Percentage active: 91.2%.
# "E - 10(fld 15 wv DAPI - DAPI)": Active: 46, inactive: 11. Percentage active: 80.7%.
# "E - 10(fld 16 wv DAPI - DAPI)": Active: 1, inactive: 0. Percentage active: 100.0%.
# "E - 10(fld 17 wv DAPI - DAPI)": Active: 24, inactive: 7. Percentage active: 77.4%.
# "E - 10(fld 18 wv DAPI - DAPI)": Active: 52, inactive: 1. Percentage active: 98.1%.
# "E - 10(fld 19 wv DAPI - DAPI)": Active: 132, inactive: 15. Percentage active: 89.8%.
# "E - 10(fld 20 wv DAPI - DAPI)": Active: 29, inactive: 5. Percentage active: 85.3%.
# "E - 10(fld 21 wv DAPI - DAPI)": Active: 0, inactive: 0. Percentage active: NaN.
# "E - 10(fld 22 wv DAPI - DAPI)": Active: 37, inactive: 4. Percentage active: 90.2%.
# "E - 10(fld 23 wv DAPI - DAPI)": Active: 67, inactive: 19. Percentage active: 77.9%.
# "E - 10(fld 24 wv DAPI - DAPI)": Active: 49, inactive: 7. Percentage active: 87.5%.
# "E - 10(fld 25 wv DAPI - DAPI)": Active: 0, inactive: 0. Percentage active: NaN.
# "F - 07(fld 01 wv DAPI - DAPI)": Active: 26, inactive: 15. Percentage active: 63.4%.
# "F - 07(fld 02 wv DAPI - DAPI)": Active: 25, inactive: 159. Percentage active: 13.6%.
# "F - 07(fld 03 wv DAPI - DAPI)": Active: 25, inactive: 196. Percentage active: 11.3%.
# "F - 07(fld 04 wv DAPI - DAPI)": Active: 22, inactive: 62. Percentage active: 26.2%.
# "F - 07(fld 05 wv DAPI - DAPI)": Active: 6, inactive: 1. Percentage active: 85.7%.
# "F - 07(fld 06 wv DAPI - DAPI)": Active: 4, inactive: 110. Percentage active: 3.5%.
# "F - 07(fld 07 wv DAPI - DAPI)": Active: 0, inactive: 185. Percentage active: 0.0%.
# "F - 07(fld 08 wv DAPI - DAPI)": Active: 0, inactive: 234. Percentage active: 0.0%.
# "F - 07(fld 09 wv DAPI - DAPI)": Active: 4, inactive: 162. Percentage active: 2.4%.
# "F - 07(fld 10 wv DAPI - DAPI)": Active: 16, inactive: 15. Percentage active: 51.6%.
# "F - 07(fld 11 wv DAPI - DAPI)": Active: 14, inactive: 166. Percentage active: 7.8%.
# "F - 07(fld 12 wv DAPI - DAPI)": Active: 1, inactive: 187. Percentage active: 0.5%.
# "F - 07(fld 13 wv DAPI - DAPI)": Active: 0, inactive: 167. Percentage active: 0.0%.
# "F - 07(fld 14 wv DAPI - DAPI)": Active: 2, inactive: 186. Percentage active: 1.1%.
# "F - 07(fld 15 wv DAPI - DAPI)": Active: 28, inactive: 38. Percentage active: 42.4%.
# "F - 07(fld 16 wv DAPI - DAPI)": Active: 33, inactive: 142. Percentage active: 18.9%.
# "F - 07(fld 17 wv DAPI - DAPI)": Active: 5, inactive: 156. Percentage active: 3.1%.
# "F - 07(fld 18 wv DAPI - DAPI)": Active: 2, inactive: 128. Percentage active: 1.5%.
# "F - 07(fld 19 wv DAPI - DAPI)": Active: 6, inactive: 214. Percentage active: 2.7%.
# "F - 07(fld 20 wv DAPI - DAPI)": Active: 34, inactive: 17. Percentage active: 66.7%.
# "F - 07(fld 21 wv DAPI - DAPI)": Active: 0, inactive: 0. Percentage active: NaN.
# "F - 07(fld 22 wv DAPI - DAPI)": Active: 0, inactive: 0. Percentage active: NaN.
# "F - 07(fld 23 wv DAPI - DAPI)": Active: 0, inactive: 1. Percentage active: 0.0%.
# "F - 07(fld 24 wv DAPI - DAPI)": Active: 28, inactive: 16. Percentage active: 63.6%.
# "F - 07(fld 25 wv DAPI - DAPI)": Active: 0, inactive: 0. Percentage active: NaN.
# "F - 08(fld 01 wv DAPI - DAPI)": Active: 0, inactive: 0. Percentage active: NaN.
# "F - 08(fld 02 wv DAPI - DAPI)": Active: 0, inactive: 0. Percentage active: NaN.
# "F - 08(fld 03 wv DAPI - DAPI)": Active: 1, inactive: 6. Percentage active: 14.3%.
# "F - 08(fld 04 wv DAPI - DAPI)": Active: 76, inactive: 5. Percentage active: 93.8%.
# "F - 08(fld 05 wv DAPI - DAPI)": Active: 0, inactive: 0. Percentage active: NaN.
# "F - 08(fld 06 wv DAPI - DAPI)": Active: 0, inactive: 0. Percentage active: NaN.
# "F - 08(fld 07 wv DAPI - DAPI)": Active: 0, inactive: 0. Percentage active: NaN.
# "F - 08(fld 08 wv DAPI - DAPI)": Active: 0, inactive: 2. Percentage active: 0.0%.
# "F - 08(fld 09 wv DAPI - DAPI)": Active: 1, inactive: 3. Percentage active: 25.0%.
# "F - 08(fld 10 wv DAPI - DAPI)": Active: 5, inactive: 3. Percentage active: 62.5%.
# "F - 08(fld 11 wv DAPI - DAPI)": Active: 0, inactive: 0. Percentage active: NaN.
# "F - 08(fld 12 wv DAPI - DAPI)": Active: 0, inactive: 0. Percentage active: NaN.
# "F - 08(fld 13 wv DAPI - DAPI)": Active: 40, inactive: 39. Percentage active: 50.6%.
# "F - 08(fld 14 wv DAPI - DAPI)": Active: 79, inactive: 5. Percentage active: 94.0%.
# "F - 08(fld 15 wv DAPI - DAPI)": Active: 6, inactive: 2. Percentage active: 75.0%.
# "F - 08(fld 16 wv DAPI - DAPI)": Active: 0, inactive: 0. Percentage active: NaN.
# "F - 08(fld 17 wv DAPI - DAPI)": Active: 0, inactive: 0. Percentage active: NaN.
# "F - 08(fld 18 wv DAPI - DAPI)": Active: 72, inactive: 2. Percentage active: 97.3%.
# "F - 08(fld 19 wv DAPI - DAPI)": Active: 105, inactive: 15. Percentage active: 87.5%.
# "F - 08(fld 20 wv DAPI - DAPI)": Active: 16, inactive: 8. Percentage active: 66.7%.
# "F - 08(fld 21 wv DAPI - DAPI)": Active: 0, inactive: 0. Percentage active: NaN.
# "F - 08(fld 22 wv DAPI - DAPI)": Active: 0, inactive: 0. Percentage active: NaN.
# "F - 08(fld 23 wv DAPI - DAPI)": Active: 1, inactive: 1. Percentage active: 50.0%.
# "F - 08(fld 24 wv DAPI - DAPI)": Active: 0, inactive: 1. Percentage active: 0.0%.
# "F - 08(fld 25 wv DAPI - DAPI)": Active: 0, inactive: 0. Percentage active: NaN.
# "F - 09(fld 01 wv DAPI - DAPI)": Active: 53, inactive: 6. Percentage active: 89.8%.
# "F - 09(fld 02 wv DAPI - DAPI)": Active: 81, inactive: 6. Percentage active: 93.1%.
# "F - 09(fld 03 wv DAPI - DAPI)": Active: 93, inactive: 2. Percentage active: 97.9%.
# "F - 09(fld 04 wv DAPI - DAPI)": Active: 76, inactive: 5. Percentage active: 93.8%.
# "F - 09(fld 05 wv DAPI - DAPI)": Active: 7, inactive: 1. Percentage active: 87.5%.
# "F - 09(fld 06 wv DAPI - DAPI)": Active: 140, inactive: 13. Percentage active: 91.5%.
# "F - 09(fld 07 wv DAPI - DAPI)": Active: 110, inactive: 4. Percentage active: 96.5%.
# "F - 09(fld 08 wv DAPI - DAPI)": Active: 74, inactive: 4. Percentage active: 94.9%.
# "F - 09(fld 09 wv DAPI - DAPI)": Active: 71, inactive: 12. Percentage active: 85.5%.
# "F - 09(fld 10 wv DAPI - DAPI)": Active: 45, inactive: 6. Percentage active: 88.2%.
# "F - 09(fld 11 wv DAPI - DAPI)": Active: 125, inactive: 9. Percentage active: 93.3%.
# "F - 09(fld 12 wv DAPI - DAPI)": Active: 69, inactive: 2. Percentage active: 97.2%.
# "F - 09(fld 13 wv DAPI - DAPI)": Active: 69, inactive: 29. Percentage active: 70.4%.
# "F - 09(fld 14 wv DAPI - DAPI)": Active: 104, inactive: 16. Percentage active: 86.7%.
# "F - 09(fld 15 wv DAPI - DAPI)": Active: 61, inactive: 8. Percentage active: 88.4%.
# "F - 09(fld 16 wv DAPI - DAPI)": Active: 62, inactive: 20. Percentage active: 75.6%.
# "F - 09(fld 17 wv DAPI - DAPI)": Active: 62, inactive: 1. Percentage active: 98.4%.
# "F - 09(fld 18 wv DAPI - DAPI)": Active: 95, inactive: 9. Percentage active: 91.3%.
# "F - 09(fld 19 wv DAPI - DAPI)": Active: 143, inactive: 8. Percentage active: 94.7%.
# "F - 09(fld 20 wv DAPI - DAPI)": Active: 47, inactive: 6. Percentage active: 88.7%.
# "F - 09(fld 21 wv DAPI - DAPI)": Active: 16, inactive: 4. Percentage active: 80.0%.
# "F - 09(fld 22 wv DAPI - DAPI)": Active: 69, inactive: 4. Percentage active: 94.5%.
# "F - 09(fld 23 wv DAPI - DAPI)": Active: 89, inactive: 67. Percentage active: 57.1%.
# "F - 09(fld 24 wv DAPI - DAPI)": Active: 78, inactive: 10. Percentage active: 88.6%.
# "F - 09(fld 25 wv DAPI - DAPI)": Active: 0, inactive: 0. Percentage active: NaN.
# "F - 10(fld 01 wv DAPI - DAPI)": Active: 0, inactive: 0. Percentage active: NaN.
# "F - 10(fld 02 wv DAPI - DAPI)": Active: 89, inactive: 7. Percentage active: 92.7%.
# "F - 10(fld 03 wv DAPI - DAPI)": Active: 151, inactive: 13. Percentage active: 92.1%.
# "F - 10(fld 04 wv DAPI - DAPI)": Active: 145, inactive: 18. Percentage active: 89.0%.
# "F - 10(fld 05 wv DAPI - DAPI)": Active: 12, inactive: 1. Percentage active: 92.3%.
# "F - 10(fld 06 wv DAPI - DAPI)": Active: 6, inactive: 5. Percentage active: 54.5%.
# "F - 10(fld 07 wv DAPI - DAPI)": Active: 99, inactive: 10. Percentage active: 90.8%.
# "F - 10(fld 08 wv DAPI - DAPI)": Active: 148, inactive: 14. Percentage active: 91.4%.
# "F - 10(fld 09 wv DAPI - DAPI)": Active: 192, inactive: 31. Percentage active: 86.1%.
# "F - 10(fld 10 wv DAPI - DAPI)": Active: 88, inactive: 16. Percentage active: 84.6%.
# "F - 10(fld 11 wv DAPI - DAPI)": Active: 0, inactive: 1. Percentage active: 0.0%.
# "F - 10(fld 12 wv DAPI - DAPI)": Active: 1, inactive: 2. Percentage active: 33.3%.
# "F - 10(fld 13 wv DAPI - DAPI)": Active: 144, inactive: 6. Percentage active: 96.0%.
# "F - 10(fld 14 wv DAPI - DAPI)": Active: 200, inactive: 25. Percentage active: 88.9%.
# "F - 10(fld 15 wv DAPI - DAPI)": Active: 129, inactive: 26. Percentage active: 83.2%.
# "F - 10(fld 16 wv DAPI - DAPI)": Active: 0, inactive: 0. Percentage active: NaN.
# "F - 10(fld 17 wv DAPI - DAPI)": Active: 47, inactive: 3. Percentage active: 94.0%.
# "F - 10(fld 18 wv DAPI - DAPI)": Active: 11, inactive: 8. Percentage active: 57.9%.
# "F - 10(fld 19 wv DAPI - DAPI)": Active: 170, inactive: 17. Percentage active: 90.9%.
# "F - 10(fld 20 wv DAPI - DAPI)": Active: 37, inactive: 3. Percentage active: 92.5%.
# "F - 10(fld 21 wv DAPI - DAPI)": Active: 0, inactive: 0. Percentage active: NaN.
# "F - 10(fld 22 wv DAPI - DAPI)": Active: 64, inactive: 9. Percentage active: 87.7%.
# "F - 10(fld 23 wv DAPI - DAPI)": Active: 92, inactive: 18. Percentage active: 83.6%.
# "F - 10(fld 24 wv DAPI - DAPI)": Active: 57, inactive: 6. Percentage active: 90.5%.
# "F - 10(fld 25 wv DAPI - DAPI)": Active: 0, inactive: 0. Percentage active: NaN.
# "G - 07(fld 01 wv DAPI - DAPI)": Active: 21, inactive: 24. Percentage active: 46.7%.
# "G - 07(fld 02 wv DAPI - DAPI)": Active: 6, inactive: 69. Percentage active: 8.0%.
# "G - 07(fld 03 wv DAPI - DAPI)": Active: 8, inactive: 83. Percentage active: 8.8%.
# "G - 07(fld 04 wv DAPI - DAPI)": Active: 0, inactive: 17. Percentage active: 0.0%.
# "G - 07(fld 05 wv DAPI - DAPI)": Active: 0, inactive: 0. Percentage active: NaN.
# "G - 07(fld 06 wv DAPI - DAPI)": Active: 3, inactive: 74. Percentage active: 3.9%.
# "G - 07(fld 07 wv DAPI - DAPI)": Active: 0, inactive: 66. Percentage active: 0.0%.
# "G - 07(fld 08 wv DAPI - DAPI)": Active: 0, inactive: 78. Percentage active: 0.0%.
# "G - 07(fld 09 wv DAPI - DAPI)": Active: 2, inactive: 50. Percentage active: 3.8%.
# "G - 07(fld 10 wv DAPI - DAPI)": Active: 0, inactive: 2. Percentage active: 0.0%.
# "G - 07(fld 11 wv DAPI - DAPI)": Active: 1, inactive: 53. Percentage active: 1.9%.
# "G - 07(fld 12 wv DAPI - DAPI)": Active: 0, inactive: 53. Percentage active: 0.0%.
# "G - 07(fld 13 wv DAPI - DAPI)": Active: 0, inactive: 119. Percentage active: 0.0%.
# "G - 07(fld 14 wv DAPI - DAPI)": Active: 0, inactive: 44. Percentage active: 0.0%.
# "G - 07(fld 15 wv DAPI - DAPI)": Active: 6, inactive: 3. Percentage active: 66.7%.
# "G - 07(fld 16 wv DAPI - DAPI)": Active: 0, inactive: 22. Percentage active: 0.0%.
# "G - 07(fld 17 wv DAPI - DAPI)": Active: 0, inactive: 27. Percentage active: 0.0%.
# "G - 07(fld 18 wv DAPI - DAPI)": Active: 1, inactive: 28. Percentage active: 3.4%.
# "G - 07(fld 19 wv DAPI - DAPI)": Active: 16, inactive: 192. Percentage active: 7.7%.
# "G - 07(fld 20 wv DAPI - DAPI)": Active: 3, inactive: 7. Percentage active: 30.0%.
# "G - 07(fld 21 wv DAPI - DAPI)": Active: 2, inactive: 0. Percentage active: 100.0%.
# "G - 07(fld 22 wv DAPI - DAPI)": Active: 0, inactive: 15. Percentage active: 0.0%.
# "G - 07(fld 23 wv DAPI - DAPI)": Active: 3, inactive: 29. Percentage active: 9.4%.
# "G - 07(fld 24 wv DAPI - DAPI)": Active: 0, inactive: 2. Percentage active: 0.0%.
# "G - 07(fld 25 wv DAPI - DAPI)": Active: 0, inactive: 0. Percentage active: NaN.
# "G - 08(fld 01 wv DAPI - DAPI)": Active: 0, inactive: 0. Percentage active: NaN.
# "G - 08(fld 02 wv DAPI - DAPI)": Active: 0, inactive: 0. Percentage active: NaN.
# "G - 08(fld 03 wv DAPI - DAPI)": Active: 23, inactive: 9. Percentage active: 71.9%.
# "G - 08(fld 04 wv DAPI - DAPI)": Active: 3, inactive: 1. Percentage active: 75.0%.
# "G - 08(fld 05 wv DAPI - DAPI)": Active: 0, inactive: 0. Percentage active: NaN.
# "G - 08(fld 06 wv DAPI - DAPI)": Active: 0, inactive: 0. Percentage active: NaN.
# "G - 08(fld 07 wv DAPI - DAPI)": Active: 71, inactive: 19. Percentage active: 78.9%.
# "G - 08(fld 08 wv DAPI - DAPI)": Active: 118, inactive: 8. Percentage active: 93.7%.
# "G - 08(fld 09 wv DAPI - DAPI)": Active: 79, inactive: 23. Percentage active: 77.5%.
# "G - 08(fld 10 wv DAPI - DAPI)": Active: 1, inactive: 0. Percentage active: 100.0%.
# "G - 08(fld 11 wv DAPI - DAPI)": Active: 1, inactive: 1. Percentage active: 50.0%.
# "G - 08(fld 12 wv DAPI - DAPI)": Active: 87, inactive: 29. Percentage active: 75.0%.
# "G - 08(fld 13 wv DAPI - DAPI)": Active: 127, inactive: 5. Percentage active: 96.2%.
# "G - 08(fld 14 wv DAPI - DAPI)": Active: 100, inactive: 25. Percentage active: 80.0%.
# "G - 08(fld 15 wv DAPI - DAPI)": Active: 0, inactive: 0. Percentage active: NaN.
# "G - 08(fld 16 wv DAPI - DAPI)": Active: 0, inactive: 0. Percentage active: NaN.
# "G - 08(fld 17 wv DAPI - DAPI)": Active: 20, inactive: 8. Percentage active: 71.4%.
# "G - 08(fld 18 wv DAPI - DAPI)": Active: 0, inactive: 2. Percentage active: 0.0%.
# "G - 08(fld 19 wv DAPI - DAPI)": Active: 0, inactive: 0. Percentage active: NaN.
# "G - 08(fld 20 wv DAPI - DAPI)": Active: 0, inactive: 0. Percentage active: NaN.
# "G - 08(fld 21 wv DAPI - DAPI)": Active: 0, inactive: 0. Percentage active: NaN.
# "G - 08(fld 22 wv DAPI - DAPI)": Active: 3, inactive: 2. Percentage active: 60.0%.
# "G - 08(fld 23 wv DAPI - DAPI)": Active: 0, inactive: 4. Percentage active: 0.0%.
# "G - 08(fld 24 wv DAPI - DAPI)": Active: 1, inactive: 1. Percentage active: 50.0%.
# "G - 08(fld 25 wv DAPI - DAPI)": Active: 0, inactive: 0. Percentage active: NaN.
# "G - 09(fld 01 wv DAPI - DAPI)": Active: 78, inactive: 9. Percentage active: 89.7%.
# "G - 09(fld 02 wv DAPI - DAPI)": Active: 132, inactive: 18. Percentage active: 88.0%.
# "G - 09(fld 03 wv DAPI - DAPI)": Active: 121, inactive: 14. Percentage active: 89.6%.
# "G - 09(fld 04 wv DAPI - DAPI)": Active: 99, inactive: 14. Percentage active: 87.6%.
# "G - 09(fld 05 wv DAPI - DAPI)": Active: 6, inactive: 0. Percentage active: 100.0%.
# "G - 09(fld 06 wv DAPI - DAPI)": Active: 120, inactive: 9. Percentage active: 93.0%.
# "G - 09(fld 07 wv DAPI - DAPI)": Active: 146, inactive: 11. Percentage active: 93.0%.
# "G - 09(fld 08 wv DAPI - DAPI)": Active: 0, inactive: 0. Percentage active: NaN.
# "G - 09(fld 09 wv DAPI - DAPI)": Active: 169, inactive: 16. Percentage active: 91.4%.
# "G - 09(fld 10 wv DAPI - DAPI)": Active: 29, inactive: 11. Percentage active: 72.5%.
# "G - 09(fld 11 wv DAPI - DAPI)": Active: 57, inactive: 3. Percentage active: 95.0%.
# "G - 09(fld 12 wv DAPI - DAPI)": Active: 86, inactive: 9. Percentage active: 90.5%.
# "G - 09(fld 13 wv DAPI - DAPI)": Active: 69, inactive: 12. Percentage active: 85.2%.
# "G - 09(fld 14 wv DAPI - DAPI)": Active: 81, inactive: 8. Percentage active: 91.0%.
# "G - 09(fld 15 wv DAPI - DAPI)": Active: 48, inactive: 9. Percentage active: 84.2%.
# "G - 09(fld 16 wv DAPI - DAPI)": Active: 71, inactive: 8. Percentage active: 89.9%.
# "G - 09(fld 17 wv DAPI - DAPI)": Active: 90, inactive: 10. Percentage active: 90.0%.
# "G - 09(fld 18 wv DAPI - DAPI)": Active: 94, inactive: 5. Percentage active: 94.9%.
# "G - 09(fld 19 wv DAPI - DAPI)": Active: 136, inactive: 9. Percentage active: 93.8%.
# "G - 09(fld 20 wv DAPI - DAPI)": Active: 66, inactive: 11. Percentage active: 85.7%.
# "G - 09(fld 21 wv DAPI - DAPI)": Active: 21, inactive: 2. Percentage active: 91.3%.
# "G - 09(fld 22 wv DAPI - DAPI)": Active: 118, inactive: 19. Percentage active: 86.1%.
# "G - 09(fld 23 wv DAPI - DAPI)": Active: 130, inactive: 17. Percentage active: 88.4%.
# "G - 09(fld 24 wv DAPI - DAPI)": Active: 56, inactive: 4. Percentage active: 93.3%.
# "G - 09(fld 25 wv DAPI - DAPI)": Active: 0, inactive: 0. Percentage active: NaN.
# "G - 10(fld 01 wv DAPI - DAPI)": Active: 14, inactive: 3. Percentage active: 82.4%.
# "G - 10(fld 02 wv DAPI - DAPI)": Active: 65, inactive: 30. Percentage active: 68.4%.
# "G - 10(fld 03 wv DAPI - DAPI)": Active: 73, inactive: 11. Percentage active: 86.9%.
# "G - 10(fld 04 wv DAPI - DAPI)": Active: 65, inactive: 27. Percentage active: 70.7%.
# "G - 10(fld 05 wv DAPI - DAPI)": Active: 7, inactive: 2. Percentage active: 77.8%.
# "G - 10(fld 06 wv DAPI - DAPI)": Active: 33, inactive: 7. Percentage active: 82.5%.
# "G - 10(fld 07 wv DAPI - DAPI)": Active: 52, inactive: 2. Percentage active: 96.3%.
# "G - 10(fld 08 wv DAPI - DAPI)": Active: 117, inactive: 8. Percentage active: 93.6%.
# "G - 10(fld 09 wv DAPI - DAPI)": Active: 143, inactive: 9. Percentage active: 94.1%.
# "G - 10(fld 10 wv DAPI - DAPI)": Active: 10, inactive: 2. Percentage active: 83.3%.
# "G - 10(fld 11 wv DAPI - DAPI)": Active: 7, inactive: 1. Percentage active: 87.5%.
# "G - 10(fld 12 wv DAPI - DAPI)": Active: 0, inactive: 0. Percentage active: NaN.
# "G - 10(fld 13 wv DAPI - DAPI)": Active: 22, inactive: 3. Percentage active: 88.0%.
# "G - 10(fld 14 wv DAPI - DAPI)": Active: 68, inactive: 3. Percentage active: 95.8%.
# "G - 10(fld 15 wv DAPI - DAPI)": Active: 29, inactive: 1. Percentage active: 96.7%.
# "G - 10(fld 16 wv DAPI - DAPI)": Active: 7, inactive: 5. Percentage active: 58.3%.
# "G - 10(fld 17 wv DAPI - DAPI)": Active: 53, inactive: 17. Percentage active: 75.7%.
# "G - 10(fld 18 wv DAPI - DAPI)": Active: 26, inactive: 1. Percentage active: 96.3%.
# "G - 10(fld 19 wv DAPI - DAPI)": Active: 86, inactive: 5. Percentage active: 94.5%.
# "G - 10(fld 20 wv DAPI - DAPI)": Active: 50, inactive: 0. Percentage active: 100.0%.
# "G - 10(fld 21 wv DAPI - DAPI)": Active: 0, inactive: 0. Percentage active: NaN.
# "G - 10(fld 22 wv DAPI - DAPI)": Active: 117, inactive: 7. Percentage active: 94.4%.
# "G - 10(fld 23 wv DAPI - DAPI)": Active: 106, inactive: 13. Percentage active: 89.1%.
# "G - 10(fld 24 wv DAPI - DAPI)": Active: 49, inactive: 6. Percentage active: 89.1%.
# "G - 10(fld 25 wv DAPI - DAPI)": Active: 0, inactive: 0. Percentage active: NaN.
# Analysis complete! Results saved to c:\Users\jasmi\Desktop\jasmin_pixel\GFP\7 days\_7 days_Intensity_Results.csv.

# %%
# %matplotlib widget
if False:
    plt.close()
    for i in range(len(images)):
        int_img = images[i][1]
        plt.figure()
        plt.axis('off')
        plt.title(images[i][0])
        plt.imshow(int_img, cmap='gray')
        contours = measure.find_contours(all_interior_list[i], level=0.5)
        for contour in contours:
            plt.plot(contour[:, 1], contour[:, 0], 'r-', linewidth=0.5)
        plt.show()

# %%
# %matplotlib widget
from scipy.ndimage import gaussian_filter
plt.close()
for i in range(len(images)):
    int_img = images[i][1]
    plt.figure()
    plt.axis('off')
    plt.title(images[i][0])
    plt.imshow(int_img, cmap='gray')
    # plt.imshow(int_img, cmap='gray', vmin=-1, vmax=1)

    if (np.sum(all_perinuclear_active_list[i])) > 0:
        contours_active = measure.find_contours(all_perinuclear_active_list[i], level=0.5)
        for contour in contours_active:
            plt.plot(contour[:, 1], contour[:, 0], 'b-', linewidth=0.5)

    if (np.sum(all_perinuclear_inactive_list[i])) > 0:
        contours_inactive = measure.find_contours(all_perinuclear_inactive_list[i], level=0.5)
        for contour in contours_inactive:
            plt.plot(contour[:, 1], contour[:, 0], 'r-', linewidth=0.5)
    plt.colorbar()
    plt.show()

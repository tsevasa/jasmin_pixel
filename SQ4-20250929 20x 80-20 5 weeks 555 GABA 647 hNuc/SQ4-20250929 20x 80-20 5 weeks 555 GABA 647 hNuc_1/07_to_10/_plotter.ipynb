# %%
import csv

csv_file = "_07_to_10_Intensity_Results.csv"
prefixes = ["A - 07", "A - 08", "A - 09", "A - 10", "B - 07", "B - 08", "B - 09", "B - 10"]
num_cells_cutoff = 10

counts = {
    p: {"active": 0, "inactive": 0}
    for p in prefixes
}

with open(csv_file, newline="") as f:
    reader = csv.DictReader(f)
    
    for row in reader:
        name = row["Name"]
        
        # Find matching prefix
        matched_prefix = None
        for p in prefixes:
            if name.startswith(p):
                matched_prefix = p
                break
        
        if matched_prefix is None:
            continue
        
        num_active = int(row["NumActive"])
        num_inactive = int(row["NumInactive"])
        total_cells = num_active + num_inactive
        
        if total_cells >= num_cells_cutoff:
            counts[matched_prefix]["active"] += num_active
            counts[matched_prefix]["inactive"] += num_inactive

# Print results
for p in prefixes:
    a = counts[p]["active"]
    i = counts[p]["inactive"]
    if a + i != 0:
        print(
            f"{p}: Active percentage = {100*a/(a+i):.2f}%, "
            f"Active = {a}, Inactive = {i}, Total = {a + i}"
        )
# Out:
# A - 07: Active percentage = 23.88%, Active = 347, Inactive = 1106, Total = 1453
# A - 08: Active percentage = 33.22%, Active = 389, Inactive = 782, Total = 1171
# A - 09: Active percentage = 35.88%, Active = 404, Inactive = 722, Total = 1126
# A - 10: Active percentage = 34.62%, Active = 414, Inactive = 782, Total = 1196
# B - 07: Active percentage = 13.64%, Active = 27, Inactive = 171, Total = 198
# B - 08: Active percentage = 7.14%, Active = 5, Inactive = 65, Total = 70
